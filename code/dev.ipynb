# %%
import os
from dotenv import load_dotenv
from kiwix import Kiwix

load_dotenv()
# Out:
# True

# %%
base_url = os.getenv("KIWIX_SERVER_URL", "http://192.168.8.152:8080")
print(f"Connecting to kiwix-serve at {base_url}...\n")
# Out:
# Connecting to kiwix-serve at http://192.168.8.152:8080...

# %%
kiwix_client = Kiwix(base_url)
    
print("Fetching books...")
books = kiwix_client.get_kiwix_book()
print(f"✅ Found {len(books)} books.\n")

books
# Out:
# Fetching books...
# ✅ Found 4 books.
# [Book(client=<kiwix.client.Kiwix object at 0x10d28c440>, id='106a6b3b-25b7-dc35-90e3-499044f6370c', name='medicalsciences.stackexchange.com_en_all', title='Medical Sciences Q&A', language='eng', description='Stack Exchange Q&A for everything related to medicine and healthcare sciences', date='2026-02-02T00:00:00Z', article_count='15161', media_count='142'),
#  Book(client=<kiwix.client.Kiwix object at 0x10d28c440>, id='62c6df01-f485-b7df-8a89-65350cae808c', name='wikem_en_all', title='WikEM', language='eng', description="The world's largest emergency medicine open-access resource", date='2021-02-28T00:00:00Z', article_count='3864', media_count='1823'),
#  Book(client=<kiwix.client.Kiwix object at 0x10d28c440>, id='bfa1e3b6-1ede-5d20-d4a8-c3a331c1b7e7', name='libretexts.org_en_med', title='Medicine LibreTexts', language='eng', description='Medicine courses and bookshelves from LibreTexts.org', date='2025-01-16T00:00:00Z', article_count='23171', media_count='30785'),
#  Book(client=<kiwix.client.Kiwix object at 0x10d28c440>, id='fb7d092d-a93a-9689-8d81-510a610e0110', name='wikipedia_en_medicine', title='WikiMed Medical Encyclopedia', language='eng', description='The largest medical encyclopedia, from Wikipedia', date='2026-04-11T00:00:00Z', article_count='362501', media_count='100895')]

# %%
example_book = next((b for b in books if "medicine" in (b.name or "").lower()), books[0])
example_book
# Out:
# Book(client=<kiwix.client.Kiwix object at 0x10d28c440>, id='fb7d092d-a93a-9689-8d81-510a610e0110', name='wikipedia_en_medicine', title='WikiMed Medical Encyclopedia', language='eng', description='The largest medical encyclopedia, from Wikipedia', date='2026-04-11T00:00:00Z', article_count='362501', media_count='100895')

# %%
query = "fever"
print(f"Searching for '{query}' in book: {example_book.title} (ID: {example_book.id})...")

articles = example_book.search_article(query)
print(f"✅ Found {len(articles)} results for '{query}':")

articles
# Out:
# Searching for 'fever' in book: WikiMed Medical Encyclopedia (ID: fb7d092d-a93a-9689-8d81-510a610e0110)...
# ✅ Found 25 results for 'fever':
# [Article(title='Yellow fever', path='Yellow_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Yellow_fever', snippet='...fever Yellow fever Other names Yellow jack, yellow plague,[1] bronze john[2] A TEM micrograph of Yellow fever virus (234,000× magnification) Specialty Infectious disease Symptoms Fever, chills, muscle pain, headache, nausea, vomiting, fatigue, loss of appetite, yellow skin[3] Complications Liver failure, bleeding[3] Usual onset 3–6 days post exposure[3] Duration 3–4 days[3] Causes Yellow fever virus spread by mosquitoes[3] Diagnostic method Blood test[4] Prevention Yellow fever vaccine[3]......', book_title='WikiMed Medical Encyclopedia', word_count='12,152'),
#  Article(title='Fever', path='Fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Fever', snippet="Fever Not to be confused with Hyperthermia. For other uses, see Fever (disambiguation). Fever Other names Pyrexia, febrile response, febrile[1] Person with fever Specialty Infectious disease, pediatrics Symptoms Initially: shivering, feeling cold, chills[2] Later: flushed, sweating[3] Complications Febrile seizure[4] Causes Virus, bacteria, increase in the body's temperature set point[5][6] Diagnostic method Temperature higher than the normal range of 37.2 and 38.3\xa0°C (99.0 and 100.9\xa0°F)[1][7]......", book_title='WikiMed Medical Encyclopedia', word_count='8,042'),
#  Article(title='Q fever', path='Q_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Q_fever', snippet='...fever endocarditis, Cayenne, French Guiana: Monoclonal antibodies against C.\xa0burnetii and hematoxylin were used for staining; original magnification is ×50. Specialty Infectious diseases\xa0 Types acute, chronic[1] Risk factors Contact with livestock[2] Differential diagnosis pneumonia, influenza, brucellosis, leptospirosis, meningitis, viral hepatitis, dengue fever, malaria, other rickettsial infections[2] Q\xa0fever or query fever is a disease caused by infection with Coxiella burnetii,[1][3][4]......', book_title='WikiMed Medical Encyclopedia', word_count='6,446'),
#  Article(title='Colorado tick fever', path='Colorado_tick_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Colorado_tick_fever', snippet='...fever Other names Mountain tick fever, American tick fever, American mountain tick fever Geographic distribution of Dermacentor andersoni ticks and Colorado tick fever virus disease cases, United States, 2010–2019. Specialty Infectious disease Colorado tick fever (CTF) is a viral infection transmitted from the bite of an infected Rocky Mountain wood tick (Dermacentor andersoni). It should not be confused with the bacterial tick-borne infection, Rocky Mountain spotted fever. Colorado tick fever......', book_title='WikiMed Medical Encyclopedia', word_count='1,851'),
#  Article(title='Lassa fever', path='Lassa_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Lassa_fever', snippet='...fever Lassa fever Other names Lassa hemorrhagic fever Community education material for Lassa fever Specialty Infectious disease Symptoms Fever, headaches, bleeding[1] Complications Partial or complete, temporary or permanent hearing loss[1] Usual onset 1–3 weeks following exposure[1] Causes Lassa virus[1] Risk factors Exposure to rodents in West Africa[1] Diagnostic method Laboratory testing[1] Differential diagnosis Ebola, malaria, typhoid fever[1] Treatment Supportive[1] Prognosis ~1% risk......', book_title='WikiMed Medical Encyclopedia', word_count='6,003'),
#  Article(title='Omsk hemorrhagic fever', path='Omsk_hemorrhagic_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Omsk_hemorrhagic_fever', snippet='...fever Omsk hemorrhagic fever Specialty Infectious disease Omsk hemorrhagic fever is a viral hemorrhagic fever caused by Omsk hemorrhagic fever virus.[1] It was found in Siberia[2] and was named after an outbreak in the city of Omsk. First records of the new virus appeared around 1940–1943. Signs and symptoms There are a number of symptoms of the virus. In the first 1–8 days the first phase begins. The symptoms in this phase are: chills headache pain in the lower and upper extremities and......', book_title='WikiMed Medical Encyclopedia', word_count='1,256'),
#  Article(title='Boutonneuse fever', path='Boutonneuse_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Boutonneuse_fever', snippet='...fever Boutonneuse fever Other names Mediterranean spotted fever Typical eschar and spots on the leg of a patient with Boutonneuse fever[1] Specialty Infectious disease Boutonneuse fever (also called Mediterranean spotted fever, fièvre boutonneuse, Kenya tick typhus, Indian tick typhus, Marseilles fever, or Astrakhan fever) is a fever as a result of a rickettsial infection caused by the bacterium Rickettsia conorii and transmitted by the dog tick Rhipicephalus sanguineus. Boutonneuse fever can......', book_title='WikiMed Medical Encyclopedia', word_count='1,131'),
#  Article(title='2016 Angola and DR Congo yellow fever outbreak', path='2016_Angola_and_DR_Congo_yellow_fever_outbreak', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/2016_Angola_and_DR_Congo_yellow_fever_outbreak', snippet='...fever cases by age group in Angola, from 5 December 2015 to 4 August 2016.[2] Confirmed cases and deaths (cumulative) in the 2016 epidemic of yellow fever in Angola as of 21 July 2016[3] On 20 January 2016, the health minister of Angola reported 23 cases of yellow fever with 7 deaths among Eritrean and Congolese citizens living in Angola in Viana municipality, a suburb of the capital of Luanda. The first cases (hemorrhagic fever suspected as being yellow fever) were reported in Eritrean visitors......', book_title='WikiMed Medical Encyclopedia', word_count='5,252'),
#  Article(title='Rocky Mountain spotted fever', path='Rocky_Mountain_spotted_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Rocky_Mountain_spotted_fever', snippet='...fever Rocky Mountain spotted fever Other names Blue disease,[1] Brazilian spotted fever, Tobia fever, new world spotted fever, tick-borne typhus fever, São Paulo fever[2] Petechial rash on the arm caused by Rocky Mountain spotted fever Specialty Infectious disease Symptoms Early: Fever, headache[3] Later: Rash[3] Complications Hearing loss, loss of limbs[3] Usual onset 2 to 14 days after infection[2] Duration 2 weeks[2] Causes Rickettsia rickettsii spread by ticks[4] Diagnostic method Based on......', book_title='WikiMed Medical Encyclopedia', word_count='5,291'),
#  Article(title='Viral hemorrhagic fever', path='Viral_hemorrhagic_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Viral_hemorrhagic_fever', snippet='...fever are typically the most prevalent and severe symptoms of VHFs. There are five known families of (RNA) viruses known to cause hemorrhagic fever: Arenaviridae, Filoviridae, Flaviviridae, Hantaviridae, and Rhabdoviridae. Some VHFs are considered mild, such as nephropathia epidemica (caused by a hantavirus), while others tend to be debilitating or even lethal, such as ebola fever (caused by a filovirus). All VHFs have the potential to result in hypotension, high fever, and death. Both humans......', book_title='WikiMed Medical Encyclopedia', word_count='2,908'),
#  Article(title='Trench fever', path='Trench_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Trench_fever', snippet='...fever Trench fever Other names Wolhynia fever, shin bone fever, Meuse fever, His disease, and His–Werner disease Specialty Infectious diseases, military medicine\xa0 Symptoms Fever Duration Five days Causes Infected insect bite Prevention Body hygiene Medication Tetracycline-group antibiotics Deaths Rare Trench fever (also known as "five-day fever", "quintan fever" (Latin: febris quintana), and "urban trench fever"[1]) is a moderately serious infectious disease caused by the bacterium Bartonella......', book_title='WikiMed Medical Encyclopedia', word_count='2,744'),
#  Article(title='Rift Valley fever', path='Rift_Valley_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Rift_Valley_fever', snippet='...fever Rift Valley fever TEM micrograph of tissue infected with Rift Valley fever virus Specialty Infectious diseases, veterinary medicine\xa0 Symptoms Fever, muscle pains, headaches Complications Loss of sight, confusion, bleeding, liver problems Duration Up to a week Causes Phlebovirus spread by an infected animal or mosquito Diagnostic method Finding antibodies or the virus in the blood Prevention Vaccinating animals against the disease, decreasing mosquito bites Treatment Supportive care[1]......', book_title='WikiMed Medical Encyclopedia', word_count='3,667'),
#  Article(title='Relapsing fever', path='Relapsing_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Relapsing_fever', snippet='...fever Relapsing fever Specialty Infectious diseases\xa0 Symptoms Fever, headache, muscle pain, nausea, rash Relapsing fever is a vector-borne disease caused by infection with certain bacteria in the genus Borrelia,[1] which is transmitted through the bites of lice, soft-bodied ticks (genus Ornithodoros), or hard-bodied ticks (genus Ixodes).[2][3] Signs and symptoms Most infected people develop sickness between 5 and 15 days after they are bitten. The symptoms may include a sudden fever, chills......', book_title='WikiMed Medical Encyclopedia', word_count='1,832'),
#  Article(title='Scarlet fever', path='Scarlet_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Scarlet_fever', snippet='...fever Scarlet fever Other names Scarlatina,[1] scarletina[2] White strawberry tongue in early stage Red strawberry tongue seen in later stage Specialty Infectious disease Symptoms Sore throat, fever, headaches, swollen lymph nodes in the neck, characteristic rash[1] Complications Kidney disease, rheumatic fever, arthritis[1] Usual onset 5–15 years old[1] Causes Group A streptococcal infection[3] Diagnostic method Throat culture[1] Prevention Handwashing, not sharing personal items, staying......', book_title='WikiMed Medical Encyclopedia', word_count='7,525'),
#  Article(title='Kemerovo tickborne viral fever', path='Kemerovo_tickborne_viral_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Kemerovo_tickborne_viral_fever', snippet='...fever Kemerovo virus Virus classification (unranked): Virus Realm: Riboviria Kingdom: Orthornavirae Phylum: Duplornaviricota Class: Resentoviricetes Order: Reovirales Family: Sedoreoviridae Genus: Orbivirus Species: Great Island virus Virus: Kemerovo virus Kemerovo tickborne viral fever is an aparalytic febrile illness accompanied by meningism following tick-bite.[1] The causative agent is a zoonotic Orbivirus first described in 1963 in western Siberia by Mikhail Chumakov and coworkers.[2] The......', book_title='WikiMed Medical Encyclopedia', word_count='698'),
#  Article(title='Yellow Fever Commission', path='Yellow_Fever_Commission', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Yellow_Fever_Commission', snippet='Yellow Fever Commission Spanish English Walter Reed authored these informed consent documents in 1900 for his research on yellow fever The Yellow Fever Commission was a research team of the United States Army which researched treatment for yellow fever. The commission was originally formed as the Reed Commission by Army Surgeon General George Sternberg in 1900.[1] The medical research board was forged as a four member board consisting of Walter Reed, James Carroll, Jesse W. Lazear, and Aristides......', book_title='WikiMed Medical Encyclopedia', word_count='908'),
#  Article(title='Pappataci fever', path='Pappataci_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Pappataci_fever', snippet='...fever Pappataci fever Distribution of pappataci fever by serotype: T, Toscana, S, Sicilian; N, Naples Specialty Infectious diseases\xa0 Pappataci fever (also known as phlebotomus fever and, somewhat confusingly, sandfly fever and three-day fever) is a vector-borne febrile arboviral infection caused by three serotypes of Phlebovirus. It occurs in subtropical regions of the Eastern Hemisphere. The name, pappataci fever, comes from the Italian word for sandfly; it is the union of the words pappa......', book_title='WikiMed Medical Encyclopedia', word_count='869'),
#  Article(title='Intermittent fever', path='Intermittent_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Intermittent_fever', snippet='...fever Performance of the various types of fever a) Fever continues b) Fever continues to abrupt onset and remission c) Remittent fever d) Intermittent fever e) Undulant fever f) Relapsing fever Intermittent fever is a type or pattern of fever in which there is an interval where temperature is elevated for several hours followed by an interval when temperature drops back to normal.[1] This type of fever usually occurs during the course of an infectious disease.[2] Diagnosis of intermittent fever......', book_title='WikiMed Medical Encyclopedia', word_count='618'),
#  Article(title='Crimean–Congo hemorrhagic fever', path='Crimean%E2%80%93Congo_hemorrhagic_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Crimean%E2%80%93Congo_hemorrhagic_fever', snippet="...fever Crimean–Congo hemorrhagic fever Male diagnosed with Crimean–Congo hemorrhagic fever, 1969 Specialty Infectious disease Symptoms Fever, muscle pains, headache, vomiting, diarrhea, bleeding into the skin[1] Complications Liver failure[1] Usual onset Rapid[1] Duration Two weeks[1] Diagnostic method Detecting antibodies, the virus's RNA, or viral proteins (antigens).[1] Differential diagnosis Dengue fever, Q fever,[2] Ebola virus disease[3] Treatment Supportive care, ribavirin (off-label)......", book_title='WikiMed Medical Encyclopedia', word_count='6,540'),
#  Article(title='Pontiac fever', path='Pontiac_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Pontiac_fever', snippet="...fever resolves spontaneously and often goes undiagnosed. Both Pontiac fever and the more severe Legionnaires' disease may be caused by the same bacterium, but Pontiac fever does not include pneumonia.[1][2][3][4][5] Signs and symptoms Pontiac fever causes flu-like symptoms including fever, dry cough, shortness of breath, headaches, and muscle aches.[1] Cause Species of Legionella known to cause Pontiac fever include Legionella pneumophila, Legionella longbeachae, Legionella feeleii, Legionella......", book_title='WikiMed Medical Encyclopedia', word_count='1,483'),
#  Article(title='Rat-bite fever', path='Rat-bite_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Rat-bite_fever', snippet="...fever Not to be confused with rat fever or leptospirosis. Incisors of Black Rat (Rattus rattus) Rat-bite fever (RBF) is an acute, febrile human illness caused by bacteria transmitted by rodents, in most cases, which is passed from rodent to human by the rodent's urine or mucous secretions. Alternative names for rat-bite fever include streptobacillary fever, streptobacillosis, spirillary fever, bogger, and epidemic arthritic erythema. It is a rare disease spread by infected rodents and caused by......", book_title='WikiMed Medical Encyclopedia', word_count='2,933'),
#  Article(title='Bolivian hemorrhagic fever', path='Bolivian_hemorrhagic_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Bolivian_hemorrhagic_fever', snippet='...fever Bolivian hemorrhagic fever Other names Black typhus, ordog fever[1] Specialty Infectious disease Symptoms Fever, malaise, bleeding[2] Usual onset 3–21 Days[3] Causes Machupo Virus[4] Risk factors Exposure to the Large Vesper Mouse[5] Treatment Supportive care[4] Frequency Rare, no cases since 2008[6] Deaths 20%–41% fatality rate[7] Bolivian hemorrhagic fever (BHF), also known as black typhus or Ordog Fever, is a hemorrhagic fever and zoonotic infectious disease endemic to Bolivia after......', book_title='WikiMed Medical Encyclopedia', word_count='2,734'),
#  Article(title='Pacific Coast tick fever', path='Pacific_Coast_tick_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Pacific_Coast_tick_fever', snippet='...tick fever Causes Rickettsia philipii spread by the Pacific coast tick[2] Differential diagnosis Rickettsia parkeri rickettsiosis, Rocky Mountain spotted fever, rickettsialpox[3] Pacific Coast tick fever is an infection caused by Rickettsia philipii.[2] The disease is spread by the Pacific coast ticks.[2] Symptoms may include an eschar.[2] It is within a group known as spotted fever rickettsiosis together with Rickettsia parkeri rickettsiosis, Rocky Mountain spotted fever, and rickettsialpox.[3]......', book_title='WikiMed Medical Encyclopedia', word_count='678'),
#  Article(title='Sandfly fever Naples virus', path='Sandfly_fever_Naples_virus', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Sandfly_fever_Naples_virus', snippet='...fever Naples phlebovirus Sandfly fever Naples virus is an antigenic species of genus Phlebovirus within the family Phenuiviridae of the order Hareavirales. It is an enveloped RNA virus with a tripartite genome. Its natural reservoir is sandflies. The SFNV serogroup consists of two main serocomplexes associated with disease in humans, the Naples and Sicilian serocomplexes. Sandfly fever induces myalgia, fever, and elevated liver enzymes in humans. It is difficult to diagnose outside endemic areas......', book_title='WikiMed Medical Encyclopedia', word_count='706'),
#  Article(title='African tick bite fever', path='African_tick_bite_fever', url='http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/African_tick_bite_fever', snippet='...tick bite fever African tick bite fever Leg lesion from a Rickettsia africae infection Specialty Infectious disease Symptoms Fever, headache, muscles pains, rash[1] Complications Rare (joint inflammation)[2][3] Usual onset 4–10 days after the bite[4] Causes Rickettsia africae spread by ticks[2] Diagnostic method Based on symptoms, confirmed by culture, PCR, or immunofluorescence[3][2] Prevention Avoiding tick bites[1] Medication Doxycycline, chloramphenicol, azithromycin[2][3] Prognosis Good[2]......', book_title='WikiMed Medical Encyclopedia', word_count='2,939')]

# %%
first_article = articles[0]
print(f"\nFetching content for '{first_article.title}'...")
# try:
html, headers = first_article.get_article()

headers

print(f"✅ Retrieved article with {len(headers)} sections.")

# Example: Filter out "References" and "External links"
exclude_headers = ["References", "External links", "Further reading", "Notes"]
filtered_headers = [h for h in headers if h.name not in exclude_headers]

print(f"\nFiltered Sections ({len(filtered_headers)} remaining):")
for h in filtered_headers[:3]:  # Print first 3 to avoid spamming the console
    print(f"\n--- {h.name} ---")
    text_snippet = h.text[:150] + "..." if len(h.text) > 150 else h.text
    print(text_snippet)
    
if len(filtered_headers) > 3:
    print(f"\n... and {len(filtered_headers) - 3} more sections.")
# Out:
# Fetching content for 'Yellow fever'...
# ✅ Retrieved article with 24 sections.
#
# Filtered Sections (20 remaining):
#
# --- Introduction ---
# /* start https://en.wikipedia.org/ */
#
#
# .mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0....
#
# --- Signs and symptoms ---
# Yellow fever begins after an incubation period of three to six days. [ 19 ] Most cases cause only mild infection with fever, headache, chills, back pa...
#
# --- Complication ---
# Yellow fever can lead to death for 20% to 50% of those who develop severe disease. Jaundice, fatigue, heart rhythm problems, seizures and internal ble...
#
# ... and 17 more sections.

# %%
import os
from dotenv import load_dotenv
from kiwix import Kiwix

load_dotenv()

def main():
    base_url = os.getenv("KIWIX_SERVER_URL", "http://192.168.8.152:8080")
    print(f"Connecting to kiwix-serve at {base_url}...\n")
    
    kiwix_client = Kiwix(base_url)
    
    print("Fetching books...")
    books = kiwix_client.get_kiwix_book()
    print(f"✅ Found {len(books)} books.\n")
    
    if not books:
        print("No books found. Exiting.")
        return
        
    # Pick a specific book or fallback to the first one available
    example_book = next((b for b in books if "medicine" in (b.name or "").lower()), books[0])
    
    query = "fever"
    print(f"Searching for '{query}' in book: {example_book.title} (ID: {example_book.id})...")
    
    articles = example_book.search_article(query)
    print(f"✅ Found {len(articles)} results for '{query}':")
    
    for article in articles[:5]:
        if article.path:
            print(f" - {article.title}: {article.url}")
            if article.snippet:
                print(f"   Snippet: {article.snippet[:100]}...")
            if article.word_count:
                print(f"   Word Count: {article.word_count} words")
        else:
            print(f" - {article.title} (Pattern match)")
            
    if articles:
        first_article = articles[0]
        print(f"\nFetching content for '{first_article.title}'...")
        try:
            html, headers = first_article.get_article()
            print(f"✅ Retrieved article with {len(headers)} sections.")
            
            # Example: Filter out "References" and "External links"
            exclude_headers = ["References", "External links", "Further reading", "Notes"]
            filtered_headers = [h for h in headers if h.name not in exclude_headers]
            
            print(f"\nFiltered Sections ({len(filtered_headers)} remaining):")
            for h in filtered_headers[:3]:  # Print first 3 to avoid spamming the console
                print(f"\n--- {h.name} ---")
                text_snippet = h.text[:150] + "..." if len(h.text) > 150 else h.text
                print(text_snippet)
                
            if len(filtered_headers) > 3:
                print(f"\n... and {len(filtered_headers) - 3} more sections.")
                
        except Exception as e:
            print(f"Failed to fetch article content: {e}")

if __name__ == "__main__":
    main()
# Out:
# Connecting to kiwix-serve at http://192.168.8.152:8080...
#
# Fetching books...
# ✅ Found 4 books.
#
# Searching for 'fever' in book: WikiMed Medical Encyclopedia (ID: fb7d092d-a93a-9689-8d81-510a610e0110)...
# ✅ Found 25 results for 'fever':
#  - Yellow fever: http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Yellow_fever
#    Snippet: ...fever Yellow fever Other names Yellow jack, yellow plague,[1] bronze john[2] A TEM micrograph of ...
#    Word Count: 12,152 words
#  - Fever: http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Fever
#    Snippet: Fever Not to be confused with Hyperthermia. For other uses, see Fever (disambiguation). Fever Other ...
#    Word Count: 8,042 words
#  - Q fever: http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Q_fever
#    Snippet: ...fever endocarditis, Cayenne, French Guiana: Monoclonal antibodies against C. burnetii and hematox...
#    Word Count: 6,446 words
#  - Colorado tick fever: http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Colorado_tick_fever
#    Snippet: ...fever Other names Mountain tick fever, American tick fever, American mountain tick fever Geograph...
#    Word Count: 1,851 words
#  - Lassa fever: http://192.168.8.152:8080/content/fb7d092d-a93a-9689-8d81-510a610e0110/Lassa_fever
#    Snippet: ...fever Lassa fever Other names Lassa hemorrhagic fever Community education material for Lassa feve...
#    Word Count: 6,003 words
#
# Fetching content for 'Yellow fever'...
# ✅ Retrieved article with 24 sections.
#
# Filtered Sections (20 remaining):
#
# --- Introduction ---
# /* start https://en.wikipedia.org/ */
#
#
# .mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0....
#
# --- Signs and symptoms ---
# Yellow fever begins after an incubation period of three to six days. [ 19 ] Most cases cause only mild infection with fever, headache, chills, back pa...
#
# --- Complication ---
# Yellow fever can lead to death for 20% to 50% of those who develop severe disease. Jaundice, fatigue, heart rhythm problems, seizures and internal ble...
#
# ... and 17 more sections.
